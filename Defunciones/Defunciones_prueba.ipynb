# %%
import pandas as pd
import glob
import os

# %%
# show all columns and rows
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
df = pd.read_spss('EDG_2010.sav')

# %%
df.head()
# Out:
#   codesta      prov  cant  parr  anioins  mesins  acta  estab       sexo  \
# 0     EDG  01 AZUAY   1.0  50.0   2010.0     1.0   1.0    1.0  2 MUJERES
# 1     EDG  01 AZUAY   1.0  50.0   2010.0     1.0   2.0    1.0  1 HOMBRES
# 2     EDG  01 AZUAY   1.0  50.0   2010.0     1.0   3.0    1.0  2 MUJERES
# 3     EDG  01 AZUAY   1.0  50.0   2010.0     1.0   5.0    1.0  1 HOMBRES
# 4     EDG  01 AZUAY   1.0  50.0   2010.0     1.0   6.0    1.0  1 HOMBRES
#
#     anion  mesn   aniof  mesf  edad cod_eda     provf  cantf  parrf     zonaf  \
# 0  1939.0  10.0  2010.0   1.0  70.0  4 AÑOS  01 AZUAY    1.0   50.0  1 URBANA
# 1  1925.0  11.0  2010.0   1.0  84.0  4 AÑOS  01 AZUAY    1.0   50.0  1 URBANA
# 2  1921.0  12.0  2010.0   1.0  88.0  4 AÑOS  01 AZUAY    1.0   50.0  1 URBANA
# 3  1949.0  12.0  2010.0   1.0  60.0  4 AÑOS  01 AZUAY    1.0   50.0  1 URBANA
# 4  2005.0  12.0  2010.0   1.0   4.0  4 AÑOS  01 AZUAY    1.0   50.0  1 URBANA
#
# ...
